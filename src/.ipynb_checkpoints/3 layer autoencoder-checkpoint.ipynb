# %%
import torch
import matplotlib.pyplot as plt
from MLP_trainer import MLP
from torch.utils.data import Dataset, DataLoader

# %%
input_size = 784
batch_size = 64
hidden_size = 100
num_classes = 10
learning_rate = 0.001
num_epochs = 10
model_num=0

# %%
# Out:
# torch.Size([78400])
# torch.Size([78400])
# torch.Size([78400])
# torch.Size([78400])
# torch.Size([313600])
# torch.Size([3136, 100])

# %%
class Weight(Dataset):
    def __init__(self, X):
        self.X = X
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        return self.X[index, :]

# %%
for i, row in enumerate(data_loader):
    print(row.size())
    print(i)
# Out:
# torch.Size([784, 100])
# 0
# torch.Size([784, 100])
# 1
# torch.Size([784, 100])
# 2
# torch.Size([784, 100])
# 3

# %%
class AE(torch.nn.Module):
    def __init__(self):
        super().__init__()
          
        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(100, 10),
        )
          

        self.decoder = torch.nn.Sequential(
            torch.nn.Linear(10, 100),
        )
  
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs = 100
outputs = []
losses = []
for epoch in range(epochs):
    for weight in data_loader:
        optimizer.zero_grad()
        outputs = model_ae(weight)
        loss = loss_function(outputs, weight)
        loss.backward()
        optimizer.step()
        losses.append(loss.detach())
  
# Defining the Plot Style
plt.style.use('fivethirtyeight')
plt.xlabel('Iterations')
plt.ylabel('Loss')
  
# Plotting the last 100 values
plt.plot(losses)

# %%
print(losses[-1])
# Out:
# tensor(0.0163)

# %% [markdown]
# ### Use the new model to evaluate MNIST

# %%
import torchvision
import torchvision.transforms as transforms


device = torch.device('cude' if torch.cuda.is_available() else 'cpu')

# hyperparameters
input_size = 784
batch_size = 64
hidden_size = 100
num_classes = 10
learning_rate = 0.001
num_epochs = 10
model_num=0

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='../data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='../data',
                                          train=False,
                                          transform=transforms.ToTensor())


# Data Loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)
def evaluate_model(model):
    # Test the model
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.reshape(-1, input_size).to(device)
            labels = labels.to(device)
            output = model(images)
            _, predicted = torch.max(output.data, 1)
            total += labels.size(0)
            correct += (predicted==labels).sum().item()
        print(f'Accuracy of the network on the test images: {100 * correct/total}%')
    return 100 * correct/total

# %%
def reconstruct_n_models(n):
    model = MLP(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes)
    weights = []
    for i in range(n):
        model.load_state_dict(torch.load(f'../model/model_{i}.ckpt'))
        weights.append(model.fc1.weight.data.transpose(1, 0).flatten())
    stacked_weights = torch.hstack(weights)
    all_weights = stacked_weights.reshape(-1, 100)
    data_loader = DataLoader(Weight(all_weights), batch_size=784)
    # Model Initialization
    model_ae = AE()

    # Validation using MSE Loss function
    loss_function = torch.nn.MSELoss()

    # Using an Adam Optimizer with lr = 0.1
    optimizer = torch.optim.Adam(model_ae.parameters(),
                                 lr = 1e-1,
                                 weight_decay = 1e-8)


    epochs = 100
    outputs = []
    losses = []
    for epoch in range(epochs):
        for weight in data_loader:
            optimizer.zero_grad()
            outputs = model_ae(weight)
            loss = loss_function(outputs, weight)
            loss.backward()
            optimizer.step()
            losses.append(loss.detach())

    # Defining the Plot Style
    plt.style.use('fivethirtyeight')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')

    # Plotting the last 100 values
    plt.plot(losses)

    accuracies = []
    for i in range(n):
        weights = []

        model.load_state_dict(torch.load(f'../model/model_{i}.ckpt'))
        reconstructed = model_ae(model.fc1.weight.data.transpose(1, 0))
        new_weight = torch.transpose(reconstructed.reshape(784, 100), 1, 0)
        model.fc1.weight.data = new_weight
        accuracy = evaluate_model(model)
        accuracies.append(accuracy)
    return np.mean(accuracies)

# %%
print(reconstruct_n_models(1))
# Out:
# Accuracy of the network on the test images: 80.43%
# 80.43

# %%
avg_accuracies = []
for i in range(30):
    avg_acc = reconstruct_n_models(i + 1)
    avg_accuracies.append(avg_acc)
plt.plot(avg_accuracies)
# Out:
# Accuracy of the network on the test images: 81.48%
# Accuracy of the network on the test images: 61.64%
# Accuracy of the network on the test images: 48.31%
# Accuracy of the network on the test images: 51.32%
# Accuracy of the network on the test images: 43.16%
# Accuracy of the network on the test images: 44.91%
# Accuracy of the network on the test images: 27.35%
# Accuracy of the network on the test images: 36.38%
# Accuracy of the network on the test images: 49.05%
# Accuracy of the network on the test images: 29.7%
# Accuracy of the network on the test images: 46.13%
# Accuracy of the network on the test images: 39.64%
# Accuracy of the network on the test images: 31.19%
# Accuracy of the network on the test images: 38.5%
# Accuracy of the network on the test images: 27.66%
# Accuracy of the network on the test images: 41.34%
# Accuracy of the network on the test images: 28.35%
# Accuracy of the network on the test images: 36.66%
# Accuracy of the network on the test images: 24.21%
# Accuracy of the network on the test images: 37.21%
# Accuracy of the network on the test images: 23.01%
# Accuracy of the network on the test images: 29.13%
# Accuracy of the network on the test images: 22.12%
# Accuracy of the network on the test images: 17.2%
# Accuracy of the network on the test images: 20.79%
# Accuracy of the network on the test images: 36.19%
# Accuracy of the network on the test images: 23.39%
# Accuracy of the network on the test images: 24.36%
# Accuracy of the network on the test images: 19.8%
# Accuracy of the network on the test images: 24.15%
# Accuracy of the network on the test images: 27.24%
# Accuracy of the network on the test images: 14.56%
# Accuracy of the network on the test images: 29.03%
# Accuracy of the network on the test images: 19.22%
# Accuracy of the network on the test images: 26.41%
# Accuracy of the network on the test images: 29.9%
# Accuracy of the network on the test images: 36.68%
# Accuracy of the network on the test images: 45.97%
# Accuracy of the network on the test images: 38.17%
# Accuracy of the network on the test images: 41.74%
# Accuracy of the network on the test images: 33.34%
# Accuracy of the network on the test images: 33.79%
# Accuracy of the network on the test images: 35.9%
# Accuracy of the network on the test images: 33.41%
# Accuracy of the network on the test images: 30.28%
# Accuracy of the network on the test images: 9.92%
# Accuracy of the network on the test images: 10.05%
# Accuracy of the network on the test images: 17.24%
# Accuracy of the network on the test images: 30.72%
# Accuracy of the network on the test images: 21.11%
# Accuracy of the network on the test images: 15.08%
# Accuracy of the network on the test images: 18.35%
# Accuracy of the network on the test images: 20.48%
# Accuracy of the network on the test images: 23.08%
# Accuracy of the network on the test images: 22.08%
# Accuracy of the network on the test images: 9.27%
# Accuracy of the network on the test images: 15.35%
# Accuracy of the network on the test images: 12.78%
# Accuracy of the network on the test images: 10.5%
# Accuracy of the network on the test images: 13.2%
# Accuracy of the network on the test images: 16.47%
# Accuracy of the network on the test images: 11.49%
# Accuracy of the network on the test images: 25.27%
# Accuracy of the network on the test images: 26.37%
# Accuracy of the network on the test images: 18.55%
# Accuracy of the network on the test images: 10.55%
# Accuracy of the network on the test images: 15.19%
# Accuracy of the network on the test images: 19.66%
# Accuracy of the network on the test images: 16.18%
# Accuracy of the network on the test images: 9.59%
# Accuracy of the network on the test images: 18.0%
# Accuracy of the network on the test images: 17.31%
# Accuracy of the network on the test images: 19.69%
# Accuracy of the network on the test images: 25.41%
# Accuracy of the network on the test images: 22.82%
# Accuracy of the network on the test images: 12.65%
# Accuracy of the network on the test images: 19.68%
# Accuracy of the network on the test images: 21.24%
# Accuracy of the network on the test images: 13.98%
# Accuracy of the network on the test images: 10.18%
# Accuracy of the network on the test images: 17.68%
# Accuracy of the network on the test images: 11.25%
# Accuracy of the network on the test images: 9.18%
# Accuracy of the network on the test images: 20.33%
# Accuracy of the network on the test images: 24.65%
# Accuracy of the network on the test images: 19.88%
# Accuracy of the network on the test images: 16.93%
# Accuracy of the network on the test images: 15.11%
# Accuracy of the network on the test images: 22.04%
# Accuracy of the network on the test images: 17.01%
# Accuracy of the network on the test images: 20.21%
# Accuracy of the network on the test images: 20.88%
# Accuracy of the network on the test images: 17.93%
# Accuracy of the network on the test images: 11.92%
# Accuracy of the network on the test images: 16.92%
# Accuracy of the network on the test images: 12.15%
# Accuracy of the network on the test images: 13.34%
# Accuracy of the network on the test images: 14.07%
# Accuracy of the network on the test images: 10.5%
# Accuracy of the network on the test images: 13.19%
# Accuracy of the network on the test images: 20.61%
# Accuracy of the network on the test images: 18.06%
# Accuracy of the network on the test images: 11.43%
# Accuracy of the network on the test images: 18.61%
# Accuracy of the network on the test images: 11.99%
# Accuracy of the network on the test images: 23.23%
# Accuracy of the network on the test images: 12.68%
# Accuracy of the network on the test images: 12.0%
# Accuracy of the network on the test images: 15.04%
# Accuracy of the network on the test images: 16.96%
# Accuracy of the network on the test images: 14.11%
# Accuracy of the network on the test images: 9.42%
# Accuracy of the network on the test images: 12.25%
# Accuracy of the network on the test images: 10.75%
# Accuracy of the network on the test images: 14.58%
# Accuracy of the network on the test images: 15.17%
# Accuracy of the network on the test images: 9.35%
# Accuracy of the network on the test images: 16.62%
# Accuracy of the network on the test images: 12.32%
# Accuracy of the network on the test images: 11.96%
# Accuracy of the network on the test images: 14.8%
# Accuracy of the network on the test images: 15.96%
# Accuracy of the network on the test images: 21.03%
# Accuracy of the network on the test images: 19.81%
# Accuracy of the network on the test images: 17.6%
# Accuracy of the network on the test images: 20.88%
# Accuracy of the network on the test images: 23.0%
# Accuracy of the network on the test images: 15.99%
# Accuracy of the network on the test images: 19.79%
# Accuracy of the network on the test images: 25.98%
# Accuracy of the network on the test images: 17.62%
# Accuracy of the network on the test images: 30.06%
# Accuracy of the network on the test images: 23.3%
# Accuracy of the network on the test images: 21.06%
# Accuracy of the network on the test images: 17.69%
# Accuracy of the network on the test images: 9.37%
# Accuracy of the network on the test images: 24.69%
# Accuracy of the network on the test images: 7.05%
# Accuracy of the network on the test images: 16.77%
# Accuracy of the network on the test images: 9.12%
# Accuracy of the network on the test images: 24.57%
# Accuracy of the network on the test images: 18.43%
# Accuracy of the network on the test images: 13.05%
# Accuracy of the network on the test images: 11.41%
# Accuracy of the network on the test images: 13.86%
# Accuracy of the network on the test images: 13.5%
# Accuracy of the network on the test images: 21.95%
# Accuracy of the network on the test images: 16.69%
# Accuracy of the network on the test images: 19.91%
# Accuracy of the network on the test images: 12.33%
# Accuracy of the network on the test images: 19.17%
# Accuracy of the network on the test images: 8.96%
# Accuracy of the network on the test images: 23.5%
# Accuracy of the network on the test images: 21.32%
# Accuracy of the network on the test images: 11.15%
# Accuracy of the network on the test images: 15.02%
# Accuracy of the network on the test images: 12.5%
# Accuracy of the network on the test images: 14.88%
# Accuracy of the network on the test images: 13.29%
# Accuracy of the network on the test images: 11.97%
# Accuracy of the network on the test images: 14.86%
# Accuracy of the network on the test images: 11.62%
# Accuracy of the network on the test images: 18.58%
# Accuracy of the network on the test images: 16.52%
# Accuracy of the network on the test images: 17.31%
# Accuracy of the network on the test images: 19.68%
# Accuracy of the network on the test images: 11.98%
# Accuracy of the network on the test images: 9.0%
# Accuracy of the network on the test images: 11.93%
# Accuracy of the network on the test images: 10.36%
# Accuracy of the network on the test images: 10.48%
# Accuracy of the network on the test images: 14.59%
# Accuracy of the network on the test images: 11.04%
# Accuracy of the network on the test images: 18.09%
# Accuracy of the network on the test images: 11.94%
# Accuracy of the network on the test images: 24.25%
# Accuracy of the network on the test images: 22.33%
# Accuracy of the network on the test images: 6.79%
# Accuracy of the network on the test images: 12.57%
# Accuracy of the network on the test images: 14.17%
# Accuracy of the network on the test images: 13.78%
# Accuracy of the network on the test images: 19.0%
# Accuracy of the network on the test images: 17.17%
# Accuracy of the network on the test images: 28.54%
# Accuracy of the network on the test images: 10.7%
# Accuracy of the network on the test images: 10.95%
# Accuracy of the network on the test images: 19.26%
# Accuracy of the network on the test images: 16.21%
# Accuracy of the network on the test images: 22.0%
# Accuracy of the network on the test images: 10.39%
# Accuracy of the network on the test images: 13.41%
# Accuracy of the network on the test images: 8.62%
# Accuracy of the network on the test images: 10.87%
# Accuracy of the network on the test images: 10.71%
# Accuracy of the network on the test images: 15.48%
# Accuracy of the network on the test images: 17.77%
# Accuracy of the network on the test images: 17.89%
# Accuracy of the network on the test images: 10.7%
# Accuracy of the network on the test images: 7.1%
# Accuracy of the network on the test images: 12.78%
# Accuracy of the network on the test images: 16.25%
# Accuracy of the network on the test images: 11.89%
# Accuracy of the network on the test images: 10.65%
# Accuracy of the network on the test images: 7.69%
# Accuracy of the network on the test images: 18.03%
# Accuracy of the network on the test images: 9.28%
# Accuracy of the network on the test images: 6.92%
# Accuracy of the network on the test images: 18.09%
# Accuracy of the network on the test images: 10.48%
# Accuracy of the network on the test images: 16.71%
# Accuracy of the network on the test images: 15.12%
# Accuracy of the network on the test images: 13.95%
# Accuracy of the network on the test images: 19.48%
# Accuracy of the network on the test images: 8.63%
# Accuracy of the network on the test images: 13.9%
# Accuracy of the network on the test images: 12.4%
# Accuracy of the network on the test images: 11.69%
# Accuracy of the network on the test images: 13.4%
# Accuracy of the network on the test images: 12.77%
# Accuracy of the network on the test images: 12.81%
# Accuracy of the network on the test images: 12.63%
# Accuracy of the network on the test images: 14.52%
# Accuracy of the network on the test images: 8.52%
# Accuracy of the network on the test images: 15.93%
# Accuracy of the network on the test images: 10.5%
# Accuracy of the network on the test images: 12.77%
# Accuracy of the network on the test images: 11.98%
# Accuracy of the network on the test images: 15.57%
# Accuracy of the network on the test images: 11.69%
# Accuracy of the network on the test images: 16.42%
# Accuracy of the network on the test images: 20.9%
# Accuracy of the network on the test images: 10.44%
# Accuracy of the network on the test images: 6.51%
# Accuracy of the network on the test images: 17.35%
# Accuracy of the network on the test images: 12.62%
# Accuracy of the network on the test images: 8.78%
# Accuracy of the network on the test images: 6.38%
# Accuracy of the network on the test images: 12.9%
# Accuracy of the network on the test images: 24.04%
# Accuracy of the network on the test images: 25.22%
# Accuracy of the network on the test images: 17.1%
# Accuracy of the network on the test images: 20.22%
# Accuracy of the network on the test images: 20.48%
# Accuracy of the network on the test images: 13.27%
# Accuracy of the network on the test images: 11.5%
# Accuracy of the network on the test images: 15.23%
# Accuracy of the network on the test images: 12.82%
# Accuracy of the network on the test images: 16.94%
# Accuracy of the network on the test images: 16.55%
# Accuracy of the network on the test images: 16.86%
# Accuracy of the network on the test images: 11.24%
# Accuracy of the network on the test images: 17.82%
# Accuracy of the network on the test images: 16.9%
# Accuracy of the network on the test images: 11.07%
# Accuracy of the network on the test images: 15.67%
# Accuracy of the network on the test images: 21.81%
# Accuracy of the network on the test images: 22.18%
# Accuracy of the network on the test images: 19.18%
# Accuracy of the network on the test images: 13.08%
# Accuracy of the network on the test images: 18.58%
# Accuracy of the network on the test images: 15.75%
# Accuracy of the network on the test images: 15.62%
# Accuracy of the network on the test images: 4.83%
# Accuracy of the network on the test images: 17.26%
# Accuracy of the network on the test images: 24.25%
# Accuracy of the network on the test images: 22.46%
# Accuracy of the network on the test images: 15.97%
# Accuracy of the network on the test images: 12.52%
# Accuracy of the network on the test images: 18.74%
# Accuracy of the network on the test images: 14.11%
# Accuracy of the network on the test images: 12.44%
# Accuracy of the network on the test images: 10.95%
# Accuracy of the network on the test images: 28.26%
# Accuracy of the network on the test images: 15.15%
# Accuracy of the network on the test images: 11.29%
# Accuracy of the network on the test images: 19.96%
# Accuracy of the network on the test images: 13.27%
# Accuracy of the network on the test images: 17.51%
# Accuracy of the network on the test images: 27.66%
# Accuracy of the network on the test images: 14.66%
# Accuracy of the network on the test images: 13.9%
# Accuracy of the network on the test images: 14.01%
# Accuracy of the network on the test images: 20.03%
# Accuracy of the network on the test images: 11.73%
# Accuracy of the network on the test images: 16.53%
# Accuracy of the network on the test images: 12.93%
# Accuracy of the network on the test images: 14.56%
# Accuracy of the network on the test images: 20.22%
# Accuracy of the network on the test images: 20.28%
# Accuracy of the network on the test images: 14.16%
# Accuracy of the network on the test images: 16.61%
# Accuracy of the network on the test images: 12.32%
# Accuracy of the network on the test images: 12.29%
# Accuracy of the network on the test images: 12.97%
# Accuracy of the network on the test images: 11.93%
# Accuracy of the network on the test images: 24.58%
# Accuracy of the network on the test images: 27.92%
# Accuracy of the network on the test images: 12.77%
# Accuracy of the network on the test images: 15.55%
# Accuracy of the network on the test images: 27.09%
# Accuracy of the network on the test images: 12.92%
# Accuracy of the network on the test images: 14.85%
# Accuracy of the network on the test images: 12.37%
# Accuracy of the network on the test images: 11.35%
# Accuracy of the network on the test images: 18.9%
# Accuracy of the network on the test images: 10.86%
# Accuracy of the network on the test images: 13.79%
# Accuracy of the network on the test images: 13.42%
# Accuracy of the network on the test images: 18.7%
# Accuracy of the network on the test images: 18.66%
# Accuracy of the network on the test images: 19.06%
# Accuracy of the network on the test images: 15.58%
# Accuracy of the network on the test images: 17.71%
# Accuracy of the network on the test images: 9.13%
# Accuracy of the network on the test images: 12.92%
# Accuracy of the network on the test images: 11.26%
# Accuracy of the network on the test images: 20.42%
# Accuracy of the network on the test images: 12.07%
# Accuracy of the network on the test images: 16.92%
# Accuracy of the network on the test images: 11.25%
# Accuracy of the network on the test images: 18.81%
# Accuracy of the network on the test images: 20.86%
# Accuracy of the network on the test images: 7.85%
# Accuracy of the network on the test images: 12.92%
# Accuracy of the network on the test images: 19.02%
# Accuracy of the network on the test images: 9.58%
# Accuracy of the network on the test images: 18.86%
# Accuracy of the network on the test images: 15.18%
# Accuracy of the network on the test images: 17.34%
# Accuracy of the network on the test images: 7.99%
# Accuracy of the network on the test images: 18.61%
# Accuracy of the network on the test images: 9.27%
# Accuracy of the network on the test images: 11.31%
# Accuracy of the network on the test images: 17.22%
# Accuracy of the network on the test images: 17.3%
# Accuracy of the network on the test images: 22.64%
# Accuracy of the network on the test images: 10.99%
# Accuracy of the network on the test images: 12.04%
# Accuracy of the network on the test images: 18.02%
# Accuracy of the network on the test images: 13.75%
# Accuracy of the network on the test images: 14.32%
# Accuracy of the network on the test images: 14.47%
# Accuracy of the network on the test images: 17.53%
# Accuracy of the network on the test images: 12.19%
# Accuracy of the network on the test images: 11.92%
# Accuracy of the network on the test images: 17.98%
# Accuracy of the network on the test images: 23.02%
# Accuracy of the network on the test images: 15.45%
# Accuracy of the network on the test images: 17.74%
# Accuracy of the network on the test images: 18.51%
# Accuracy of the network on the test images: 9.26%
# Accuracy of the network on the test images: 9.9%
# Accuracy of the network on the test images: 14.73%
# Accuracy of the network on the test images: 10.32%
# Accuracy of the network on the test images: 7.06%
# Accuracy of the network on the test images: 14.52%
# Accuracy of the network on the test images: 10.93%
# Accuracy of the network on the test images: 16.84%
# Accuracy of the network on the test images: 9.47%
# Accuracy of the network on the test images: 12.91%
# Accuracy of the network on the test images: 7.45%
# Accuracy of the network on the test images: 18.44%
# Accuracy of the network on the test images: 7.9%
# Accuracy of the network on the test images: 13.29%
# Accuracy of the network on the test images: 15.1%
# Accuracy of the network on the test images: 9.28%
# Accuracy of the network on the test images: 12.98%
# Accuracy of the network on the test images: 16.69%
# Accuracy of the network on the test images: 9.13%
# Accuracy of the network on the test images: 18.8%
# Accuracy of the network on the test images: 13.88%
# Accuracy of the network on the test images: 24.35%
# Accuracy of the network on the test images: 10.16%
# Accuracy of the network on the test images: 10.95%
# Accuracy of the network on the test images: 16.51%
# Accuracy of the network on the test images: 11.53%
# Accuracy of the network on the test images: 13.23%
# Accuracy of the network on the test images: 18.72%
# Accuracy of the network on the test images: 5.02%
# Accuracy of the network on the test images: 15.1%
# Accuracy of the network on the test images: 14.24%
# Accuracy of the network on the test images: 9.13%
# Accuracy of the network on the test images: 16.59%
# Accuracy of the network on the test images: 9.52%
# Accuracy of the network on the test images: 11.14%
# Accuracy of the network on the test images: 5.99%
# Accuracy of the network on the test images: 12.68%
# Accuracy of the network on the test images: 13.05%
# Accuracy of the network on the test images: 17.64%
# Accuracy of the network on the test images: 11.0%
# Accuracy of the network on the test images: 9.15%
# Accuracy of the network on the test images: 20.35%
# Accuracy of the network on the test images: 13.1%
# Accuracy of the network on the test images: 13.16%
# Accuracy of the network on the test images: 16.4%
# Accuracy of the network on the test images: 20.49%
# Accuracy of the network on the test images: 11.95%
# Accuracy of the network on the test images: 14.5%
# Accuracy of the network on the test images: 14.17%
# Accuracy of the network on the test images: 12.63%
# Accuracy of the network on the test images: 17.32%
# Accuracy of the network on the test images: 13.66%
# Accuracy of the network on the test images: 8.95%
# Accuracy of the network on the test images: 12.82%
# Accuracy of the network on the test images: 11.38%
# Accuracy of the network on the test images: 10.58%
# Accuracy of the network on the test images: 14.18%
# Accuracy of the network on the test images: 14.77%
# Accuracy of the network on the test images: 10.25%
# Accuracy of the network on the test images: 16.62%
# Accuracy of the network on the test images: 15.36%
# Accuracy of the network on the test images: 14.18%
# Accuracy of the network on the test images: 10.67%
# Accuracy of the network on the test images: 21.97%
# Accuracy of the network on the test images: 17.52%
# Accuracy of the network on the test images: 10.56%
# Accuracy of the network on the test images: 23.52%
# Accuracy of the network on the test images: 15.39%
# Accuracy of the network on the test images: 8.22%
# Accuracy of the network on the test images: 12.2%
# Accuracy of the network on the test images: 9.01%
# Accuracy of the network on the test images: 20.76%
# Accuracy of the network on the test images: 16.6%
# Accuracy of the network on the test images: 19.82%
# Accuracy of the network on the test images: 14.56%
# Accuracy of the network on the test images: 12.79%
# Accuracy of the network on the test images: 23.12%
# Accuracy of the network on the test images: 22.58%
# Accuracy of the network on the test images: 17.26%
# Accuracy of the network on the test images: 15.4%
# Accuracy of the network on the test images: 10.67%
# Accuracy of the network on the test images: 8.96%
# Accuracy of the network on the test images: 19.35%
# Accuracy of the network on the test images: 20.44%
# Accuracy of the network on the test images: 11.64%
# Accuracy of the network on the test images: 10.77%
# Accuracy of the network on the test images: 15.98%
# Accuracy of the network on the test images: 15.05%
# Accuracy of the network on the test images: 11.51%
# Accuracy of the network on the test images: 9.13%
# Accuracy of the network on the test images: 12.66%
# Accuracy of the network on the test images: 9.37%
# Accuracy of the network on the test images: 13.49%
# Accuracy of the network on the test images: 26.04%
# Accuracy of the network on the test images: 4.41%
# Accuracy of the network on the test images: 8.41%
# Accuracy of the network on the test images: 15.7%
# Accuracy of the network on the test images: 14.4%
# Accuracy of the network on the test images: 19.82%
# Accuracy of the network on the test images: 15.71%
# Accuracy of the network on the test images: 21.25%
# Accuracy of the network on the test images: 24.02%
# Accuracy of the network on the test images: 19.35%
# Accuracy of the network on the test images: 17.24%
# Accuracy of the network on the test images: 10.77%
# Accuracy of the network on the test images: 24.67%
# Accuracy of the network on the test images: 14.7%
# Accuracy of the network on the test images: 12.77%
# Accuracy of the network on the test images: 12.53%
# Accuracy of the network on the test images: 7.82%
# Accuracy of the network on the test images: 11.3%
# Accuracy of the network on the test images: 24.5%
# Accuracy of the network on the test images: 15.29%
# Accuracy of the network on the test images: 18.57%
# Accuracy of the network on the test images: 15.87%

# %%
print(avg_accuracies)
# Out:
# [81.48, 54.975, 46.46333333333333, 35.62, 36.624, 31.796666666666667, 24.740000000000002, 23.78875, 36.586666666666666, 18.810999999999996, 15.436363636363637, 18.118333333333336, 16.802307692307693, 15.114285714285716, 13.762666666666666, 19.62125, 16.174117647058825, 14.024999999999999, 15.987894736842104, 12.565999999999999, 13.599047619047615, 15.05318181818182, 16.57086956521739, 16.895, 14.864, 15.095769230769228, 13.150740740740742, 12.918214285714285, 15.461034482758619, 15.103333333333333]

# %%
import numpy as np
a = [81.48, 54.975, 46.46333333333333, 35.62, 36.624, 31.796666666666667, 24.740000000000002, 23.78875, 36.586666666666666, 18.810999999999996, 15.436363636363637, 18.118333333333336, 16.802307692307693, 15.114285714285716, 13.762666666666666, 19.62125, 16.174117647058825, 14.024999999999999, 15.987894736842104, 12.565999999999999, 13.599047619047615, 15.05318181818182, 16.57086956521739, 16.895, 14.864, 15.095769230769228, 13.150740740740742, 12.918214285714285, 15.461034482758619, 15.103333333333333]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(a)
plt.xlabel('No of Models')
plt.ylabel('Accuracy')
plt.title('Accuracy vs No of models passed through AE')
# Out:
# Text(0.5, 1.0, 'Accuracy vs No of models passed through AE')
